-- %% [markdown]
-- # [dbo].[__MigrationHistory]

-- %%
USE [WebApplication2Context-20260507124423]
GO

-- %%
/****** Object:  Table [dbo].[__MigrationHistory]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__MigrationHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ContextKey] [nvarchar](300) NOT NULL,
	[Model] [varbinary](max) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK_dbo.__MigrationHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC,
	[ContextKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[audit_log]

-- %%
/****** Object:  Table [dbo].[audit_log]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[audit_log](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[user_id] [int] NULL,
	[action] [nvarchar](max) NULL,
	[entity_type] [nvarchar](max) NULL,
	[entity_id] [int] NULL,
	[old_values] [nvarchar](max) NULL,
	[new_values] [nvarchar](max) NULL,
	[ip_address] [nvarchar](max) NULL,
	[occurred_at] [datetime] NULL,
	[users_id] [int] NULL,
 CONSTRAINT [PK_dbo.audit_log] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[batch_raw_materials]

-- %%
/****** Object:  Table [dbo].[batch_raw_materials]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[batch_raw_materials](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[batch_id] [int] NOT NULL,
	[rm_batch_id] [int] NOT NULL,
	[planned_qty] [decimal](18, 2) NULL,
	[actual_qty] [decimal](18, 2) NULL,
	[unit] [nvarchar](max) NULL,
	[added_at] [datetime] NULL,
	[added_by] [int] NULL,
	[production_batches_id] [int] NULL,
	[raw_material_batches_id] [int] NULL,
	[users_id] [int] NULL,
 CONSTRAINT [PK_dbo.batch_raw_materials] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[captcha_attempts]

-- %%
/****** Object:  Table [dbo].[captcha_attempts]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[captcha_attempts](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[session_id] [nvarchar](100) NOT NULL,
	[captcha_text] [nvarchar](10) NOT NULL,
	[created_at] [datetime] NOT NULL,
	[is_used] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[departments]

-- %%
/****** Object:  Table [dbo].[departments]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[departments](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](max) NULL,
	[description] [nvarchar](max) NULL,
 CONSTRAINT [PK_dbo.departments] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[deviations]

-- %%
/****** Object:  Table [dbo].[deviations]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[deviations](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[batch_id] [int] NOT NULL,
	[step_execution_id] [int] NULL,
	[severity] [nvarchar](max) NULL,
	[deviation_type] [nvarchar](max) NULL,
	[description] [nvarchar](max) NULL,
	[registered_by] [int] NULL,
	[registered_at] [datetime] NULL,
	[resolution_status] [nvarchar](max) NULL,
	[resolved_by] [int] NULL,
	[resolved_at] [datetime] NULL,
	[production_batches_id] [int] NULL,
	[step_executions_id] [int] NULL,
	[users_id] [int] NULL,
	[users1_id] [int] NULL,
	[users_id1] [int] NULL,
	[users_id2] [int] NULL,
 CONSTRAINT [PK_dbo.deviations] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[equipment_telemetry]

-- %%
/****** Object:  Table [dbo].[equipment_telemetry]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[equipment_telemetry](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[equipment_id] [int] NOT NULL,
	[step_exec_id] [int] NULL,
	[parameter_name] [nvarchar](max) NULL,
	[value] [decimal](18, 2) NULL,
	[unit] [nvarchar](max) NULL,
	[recorded_at] [datetime] NULL,
	[equipment_id1] [int] NULL,
	[step_executions_id] [int] NULL,
 CONSTRAINT [PK_dbo.equipment_telemetry] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[equipments]

-- %%
/****** Object:  Table [dbo].[equipments]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[equipments](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](max) NULL,
	[equipment_type] [nvarchar](max) NULL,
	[location] [nvarchar](max) NULL,
	[max_capacity] [decimal](18, 2) NULL,
	[capacity_unit] [nvarchar](max) NULL,
	[status] [nvarchar](max) NULL,
	[last_maintenance] [datetime] NULL,
 CONSTRAINT [PK_dbo.equipments] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[lab_test_history]

-- %%
/****** Object:  Table [dbo].[lab_test_history]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[lab_test_history](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[test_id] [int] NOT NULL,
	[action] [nvarchar](100) NOT NULL,
	[description] [nvarchar](500) NULL,
	[user_id] [int] NULL,
	[created_at] [datetime] NOT NULL,
	[old_value] [nvarchar](max) NULL,
	[new_value] [nvarchar](max) NULL,
 CONSTRAINT [PK_lab_test_history] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[lab_test_results]

-- %%
/****** Object:  Table [dbo].[lab_test_results]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[lab_test_results](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[test_id] [int] NOT NULL,
	[parameter_name] [nvarchar](max) NULL,
	[measured_value] [decimal](18, 2) NULL,
	[min_value] [decimal](18, 2) NULL,
	[max_value] [decimal](18, 2) NULL,
	[unit] [nvarchar](max) NULL,
	[is_within_range] [bit] NULL,
	[measured_at] [datetime] NULL,
	[lab_tests_id] [int] NULL,
 CONSTRAINT [PK_dbo.lab_test_results] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[lab_test_results_new]

-- %%
/****** Object:  Table [dbo].[lab_test_results_new]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[lab_test_results_new](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[test_id] [int] NOT NULL,
	[parameter_name] [nvarchar](200) NOT NULL,
	[measured_value] [decimal](18, 4) NULL,
	[min_value] [decimal](18, 4) NULL,
	[max_value] [decimal](18, 4) NULL,
	[unit] [nvarchar](50) NULL,
	[is_within_range] [bit] NULL,
	[measured_at] [datetime] NULL,
	[measured_by] [int] NULL,
 CONSTRAINT [PK_lab_test_results_new] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[lab_tests]

-- %%
/****** Object:  Table [dbo].[lab_tests]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[lab_tests](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[object_type] [nvarchar](max) NULL,
	[object_id] [int] NOT NULL,
	[status] [nvarchar](max) NULL,
	[lab_user_id] [int] NULL,
	[created_by] [int] NULL,
	[completed_at] [datetime] NULL,
	[decision] [nvarchar](max) NULL,
	[conclusion] [nvarchar](max) NULL,
	[users_id] [int] NULL,
	[users1_id] [int] NULL,
	[users_id1] [int] NULL,
	[users_id2] [int] NULL,
 CONSTRAINT [PK_dbo.lab_tests] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[lab_tests_new]

-- %%
/****** Object:  Table [dbo].[lab_tests_new]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[lab_tests_new](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[test_number] [nvarchar](50) NOT NULL,
	[object_type] [nvarchar](50) NOT NULL,
	[object_id] [int] NOT NULL,
	[object_name] [nvarchar](500) NULL,
	[status] [nvarchar](50) NOT NULL,
	[lab_user_id] [int] NULL,
	[created_by] [int] NULL,
	[created_at] [datetime] NOT NULL,
	[started_at] [datetime] NULL,
	[completed_at] [datetime] NULL,
	[decision] [nvarchar](50) NULL,
	[conclusion] [nvarchar](max) NULL,
	[rejection_reason] [nvarchar](max) NULL,
	[is_blocked] [bit] NOT NULL,
 CONSTRAINT [PK_lab_tests_new] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[production_batches]

-- %%
/****** Object:  Table [dbo].[production_batches]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[production_batches](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[order_id] [int] NULL,
	[batch_number] [nvarchar](max) NULL,
	[status] [nvarchar](max) NULL,
	[actual_qty] [decimal](18, 2) NULL,
	[qty_unit] [nvarchar](max) NULL,
	[started_at] [datetime] NULL,
	[finished_at] [datetime] NULL,
	[responsible_user] [int] NULL,
	[notes] [nvarchar](max) NULL,
	[production_orders_id] [int] NULL,
	[users_id] [int] NULL,
 CONSTRAINT [PK_dbo.production_batches] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[production_orders]

-- %%
/****** Object:  Table [dbo].[production_orders]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[production_orders](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[order_number] [nvarchar](max) NULL,
	[product_id] [int] NULL,
	[recipe_id] [int] NULL,
	[tech_map_id] [int] NULL,
	[planned_qty] [decimal](18, 2) NULL,
	[qty_unit] [nvarchar](max) NULL,
	[planned_date] [datetime] NOT NULL,
	[status] [nvarchar](max) NULL,
	[priority] [int] NULL,
	[created_by] [int] NULL,
	[products_id] [int] NULL,
	[recipes_id] [int] NULL,
	[tech_maps_id] [int] NULL,
	[users_id] [int] NULL,
 CONSTRAINT [PK_dbo.production_orders] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[products]

-- %%
/****** Object:  Table [dbo].[products]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[products](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](max) NULL,
	[product_type] [nvarchar](max) NULL,
	[release_form] [nvarchar](max) NULL,
	[status] [nvarchar](max) NULL,
 CONSTRAINT [PK_dbo.products] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[raw_material_batches]

-- %%
/****** Object:  Table [dbo].[raw_material_batches]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[raw_material_batches](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[material_id] [int] NOT NULL,
	[supplier_id] [int] NULL,
	[batch_number] [nvarchar](max) NULL,
	[receipt_date] [datetime] NOT NULL,
	[expiry_date] [datetime] NULL,
	[quantity_kg] [decimal](18, 2) NOT NULL,
	[remaining_qty] [decimal](18, 2) NOT NULL,
	[status] [nvarchar](max) NULL,
	[certificate_ref] [nvarchar](max) NULL,
	[raw_materials_id] [int] NULL,
	[suppliers_id] [int] NULL,
 CONSTRAINT [PK_dbo.raw_material_batches] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[raw_materials]

-- %%
/****** Object:  Table [dbo].[raw_materials]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[raw_materials](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](max) NULL,
	[unit] [nvarchar](max) NULL,
	[material_type] [nvarchar](max) NULL,
	[cas_number] [nvarchar](max) NULL,
	[specification] [nvarchar](max) NULL,
	[is_hazardous] [bit] NULL,
 CONSTRAINT [PK_dbo.raw_materials] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[recipe_components]

-- %%
/****** Object:  Table [dbo].[recipe_components]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[recipe_components](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[recipe_id] [int] NOT NULL,
	[material_id] [int] NOT NULL,
	[quantity] [decimal](18, 2) NOT NULL,
	[unit] [nvarchar](max) NULL,
	[tolerance_pct] [decimal](18, 2) NULL,
	[load_order] [int] NULL,
	[raw_materials_id] [int] NULL,
	[recipes_id] [int] NULL,
 CONSTRAINT [PK_dbo.recipe_components] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[recipes]

-- %%
/****** Object:  Table [dbo].[recipes]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[recipes](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[product_id] [int] NOT NULL,
	[version] [int] NOT NULL,
	[status] [nvarchar](max) NULL,
	[description] [nvarchar](max) NULL,
	[created_by] [int] NULL,
	[approved_by] [int] NULL,
	[approved_at] [datetime] NULL,
	[products_id] [int] NULL,
	[users_id] [int] NULL,
	[users1_id] [int] NULL,
	[users_id1] [int] NULL,
	[users_id2] [int] NULL,
 CONSTRAINT [PK_dbo.recipes] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[roles]

-- %%
/****** Object:  Table [dbo].[roles]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[roles](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](max) NULL,
	[description] [nvarchar](max) NULL,
	[permissions] [nvarchar](max) NULL,
 CONSTRAINT [PK_dbo.roles] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[step_executions]

-- %%
/****** Object:  Table [dbo].[step_executions]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[step_executions](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[batch_id] [int] NOT NULL,
	[tech_step_id] [int] NOT NULL,
	[status] [nvarchar](max) NULL,
	[started_at] [datetime] NULL,
	[finished_at] [datetime] NULL,
	[started_by] [int] NULL,
	[finished_by] [int] NULL,
	[actual_param_value] [decimal](18, 2) NULL,
	[actual_duration_min] [int] NULL,
	[comment] [nvarchar](max) NULL,
	[equipment_id] [int] NULL,
	[equipment_id1] [int] NULL,
	[tech_steps_id] [int] NULL,
	[production_batches_id] [int] NULL,
	[users_id] [int] NULL,
	[users1_id] [int] NULL,
	[users_id1] [int] NULL,
	[users_id2] [int] NULL,
 CONSTRAINT [PK_dbo.step_executions] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[suppliers]

-- %%
/****** Object:  Table [dbo].[suppliers]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[suppliers](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](max) NULL,
	[country] [nvarchar](max) NULL,
	[contact_info] [nvarchar](max) NULL,
	[is_active] [bit] NULL,
 CONSTRAINT [PK_dbo.suppliers] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tech_maps]

-- %%
/****** Object:  Table [dbo].[tech_maps]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tech_maps](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[recipe_id] [int] NOT NULL,
	[name] [nvarchar](max) NULL,
	[version] [int] NOT NULL,
	[status] [nvarchar](max) NULL,
	[equipment_id] [int] NULL,
	[created_by] [int] NULL,
	[approved_by] [int] NULL,
	[approved_at] [datetime] NULL,
	[equipment_id1] [int] NULL,
	[recipes_id] [int] NULL,
	[users_id] [int] NULL,
	[users1_id] [int] NULL,
	[users_id1] [int] NULL,
	[users_id2] [int] NULL,
 CONSTRAINT [PK_dbo.tech_maps] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tech_steps]

-- %%
/****** Object:  Table [dbo].[tech_steps]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tech_steps](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[tech_map_id] [int] NOT NULL,
	[step_number] [int] NOT NULL,
	[step_type] [nvarchar](max) NULL,
	[name] [nvarchar](max) NULL,
	[instructions] [nvarchar](max) NULL,
	[param_name] [nvarchar](max) NULL,
	[param_target] [decimal](18, 2) NULL,
	[param_min] [decimal](18, 2) NULL,
	[param_max] [decimal](18, 2) NULL,
	[param_unit] [nvarchar](max) NULL,
	[duration_min] [int] NULL,
	[is_mandatory] [bit] NULL,
	[equipment_id] [int] NULL,
	[equipment_id1] [int] NULL,
	[tech_maps_id] [int] NULL,
 CONSTRAINT [PK_dbo.tech_steps] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[test_protocol_parameters]

-- %%
/****** Object:  Table [dbo].[test_protocol_parameters]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[test_protocol_parameters](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[template_id] [int] NOT NULL,
	[parameter_name] [nvarchar](200) NOT NULL,
	[default_min_value] [decimal](18, 4) NULL,
	[default_max_value] [decimal](18, 4) NULL,
	[unit] [nvarchar](50) NULL,
	[sort_order] [int] NOT NULL,
	[is_required] [bit] NOT NULL,
 CONSTRAINT [PK_test_protocol_parameters] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[test_protocol_templates]

-- %%
/****** Object:  Table [dbo].[test_protocol_templates]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[test_protocol_templates](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](200) NOT NULL,
	[object_type] [nvarchar](50) NOT NULL,
	[material_type_id] [int] NULL,
	[product_type_id] [int] NULL,
	[is_active] [bit] NOT NULL,
	[description] [nvarchar](max) NULL,
	[created_at] [datetime] NOT NULL,
	[created_by] [int] NULL,
 CONSTRAINT [PK_test_protocol_templates] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
/****** Object:  Table [dbo].[users]    Script Date: 18.05.2026 21:24:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[username] [nvarchar](max) NULL,
	[password_hash] [nvarchar](max) NULL,
	[full_name] [nvarchar](max) NULL,
	[email] [nvarchar](max) NULL,
	[role_id] [int] NULL,
	[department_id] [int] NULL,
	[is_active] [bit] NULL,
	[last_login_at] [datetime] NULL,
	[created_at] [datetime] NULL,
	[departments_id] [int] NULL,
	[roles_id] [int] NULL,
 CONSTRAINT [PK_dbo.users] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__captcha_a__is_us__160F4887]

-- %%
ALTER TABLE [dbo].[captcha_attempts] ADD  DEFAULT ((0)) FOR [is_used]
GO

-- %% [markdown]
-- # [DF__lab_test___creat__3587F3E0]

-- %%
ALTER TABLE [dbo].[lab_test_history] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__lab_tests__statu__30C33EC3]

-- %%
ALTER TABLE [dbo].[lab_tests_new] ADD  DEFAULT ('pending') FOR [status]
GO

-- %% [markdown]
-- # [DF__lab_tests__creat__31B762FC]

-- %%
ALTER TABLE [dbo].[lab_tests_new] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__lab_tests__is_bl__32AB8735]

-- %%
ALTER TABLE [dbo].[lab_tests_new] ADD  DEFAULT ((0)) FOR [is_blocked]
GO

-- %% [markdown]
-- # [DF__test_prot__sort___2CF2ADDF]

-- %%
ALTER TABLE [dbo].[test_protocol_parameters] ADD  DEFAULT ((0)) FOR [sort_order]
GO

-- %% [markdown]
-- # [DF__test_prot__is_re__2DE6D218]

-- %%
ALTER TABLE [dbo].[test_protocol_parameters] ADD  DEFAULT ((1)) FOR [is_required]
GO

-- %% [markdown]
-- # [DF__test_prot__is_ac__29221CFB]

-- %%
ALTER TABLE [dbo].[test_protocol_templates] ADD  DEFAULT ((1)) FOR [is_active]
GO

-- %% [markdown]
-- # [DF__test_prot__creat__2A164134]

-- %%
ALTER TABLE [dbo].[test_protocol_templates] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [FK_dbo.audit_log_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[audit_log]  WITH CHECK ADD  CONSTRAINT [FK_dbo.audit_log_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[audit_log] CHECK CONSTRAINT [FK_dbo.audit_log_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.batch_raw_materials_dbo.production_batches_production_batches_id]

-- %%
ALTER TABLE [dbo].[batch_raw_materials]  WITH CHECK ADD  CONSTRAINT [FK_dbo.batch_raw_materials_dbo.production_batches_production_batches_id] FOREIGN KEY([production_batches_id])
REFERENCES [dbo].[production_batches] ([id])
GO
ALTER TABLE [dbo].[batch_raw_materials] CHECK CONSTRAINT [FK_dbo.batch_raw_materials_dbo.production_batches_production_batches_id]
GO

-- %% [markdown]
-- # [FK_dbo.batch_raw_materials_dbo.raw_material_batches_raw_material_batches_id]

-- %%
ALTER TABLE [dbo].[batch_raw_materials]  WITH CHECK ADD  CONSTRAINT [FK_dbo.batch_raw_materials_dbo.raw_material_batches_raw_material_batches_id] FOREIGN KEY([raw_material_batches_id])
REFERENCES [dbo].[raw_material_batches] ([id])
GO
ALTER TABLE [dbo].[batch_raw_materials] CHECK CONSTRAINT [FK_dbo.batch_raw_materials_dbo.raw_material_batches_raw_material_batches_id]
GO

-- %% [markdown]
-- # [FK_dbo.batch_raw_materials_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[batch_raw_materials]  WITH CHECK ADD  CONSTRAINT [FK_dbo.batch_raw_materials_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[batch_raw_materials] CHECK CONSTRAINT [FK_dbo.batch_raw_materials_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.deviations_dbo.production_batches_production_batches_id]

-- %%
ALTER TABLE [dbo].[deviations]  WITH CHECK ADD  CONSTRAINT [FK_dbo.deviations_dbo.production_batches_production_batches_id] FOREIGN KEY([production_batches_id])
REFERENCES [dbo].[production_batches] ([id])
GO
ALTER TABLE [dbo].[deviations] CHECK CONSTRAINT [FK_dbo.deviations_dbo.production_batches_production_batches_id]
GO

-- %% [markdown]
-- # [FK_dbo.deviations_dbo.step_executions_step_executions_id]

-- %%
ALTER TABLE [dbo].[deviations]  WITH CHECK ADD  CONSTRAINT [FK_dbo.deviations_dbo.step_executions_step_executions_id] FOREIGN KEY([step_executions_id])
REFERENCES [dbo].[step_executions] ([id])
GO
ALTER TABLE [dbo].[deviations] CHECK CONSTRAINT [FK_dbo.deviations_dbo.step_executions_step_executions_id]
GO

-- %% [markdown]
-- # [FK_dbo.deviations_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[deviations]  WITH CHECK ADD  CONSTRAINT [FK_dbo.deviations_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[deviations] CHECK CONSTRAINT [FK_dbo.deviations_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.deviations_dbo.users_users_id1]

-- %%
ALTER TABLE [dbo].[deviations]  WITH CHECK ADD  CONSTRAINT [FK_dbo.deviations_dbo.users_users_id1] FOREIGN KEY([users_id1])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[deviations] CHECK CONSTRAINT [FK_dbo.deviations_dbo.users_users_id1]
GO

-- %% [markdown]
-- # [FK_dbo.deviations_dbo.users_users_id2]

-- %%
ALTER TABLE [dbo].[deviations]  WITH CHECK ADD  CONSTRAINT [FK_dbo.deviations_dbo.users_users_id2] FOREIGN KEY([users_id2])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[deviations] CHECK CONSTRAINT [FK_dbo.deviations_dbo.users_users_id2]
GO

-- %% [markdown]
-- # [FK_dbo.deviations_dbo.users_users1_id]

-- %%
ALTER TABLE [dbo].[deviations]  WITH CHECK ADD  CONSTRAINT [FK_dbo.deviations_dbo.users_users1_id] FOREIGN KEY([users1_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[deviations] CHECK CONSTRAINT [FK_dbo.deviations_dbo.users_users1_id]
GO

-- %% [markdown]
-- # [FK_dbo.equipment_telemetry_dbo.equipments_equipment_id1]

-- %%
ALTER TABLE [dbo].[equipment_telemetry]  WITH CHECK ADD  CONSTRAINT [FK_dbo.equipment_telemetry_dbo.equipments_equipment_id1] FOREIGN KEY([equipment_id1])
REFERENCES [dbo].[equipments] ([id])
GO
ALTER TABLE [dbo].[equipment_telemetry] CHECK CONSTRAINT [FK_dbo.equipment_telemetry_dbo.equipments_equipment_id1]
GO

-- %% [markdown]
-- # [FK_dbo.equipment_telemetry_dbo.step_executions_step_executions_id]

-- %%
ALTER TABLE [dbo].[equipment_telemetry]  WITH CHECK ADD  CONSTRAINT [FK_dbo.equipment_telemetry_dbo.step_executions_step_executions_id] FOREIGN KEY([step_executions_id])
REFERENCES [dbo].[step_executions] ([id])
GO
ALTER TABLE [dbo].[equipment_telemetry] CHECK CONSTRAINT [FK_dbo.equipment_telemetry_dbo.step_executions_step_executions_id]
GO

-- %% [markdown]
-- # [FK_lab_test_history_tests]

-- %%
ALTER TABLE [dbo].[lab_test_history]  WITH CHECK ADD  CONSTRAINT [FK_lab_test_history_tests] FOREIGN KEY([test_id])
REFERENCES [dbo].[lab_tests_new] ([id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[lab_test_history] CHECK CONSTRAINT [FK_lab_test_history_tests]
GO

-- %% [markdown]
-- # [FK_lab_test_history_users]

-- %%
ALTER TABLE [dbo].[lab_test_history]  WITH CHECK ADD  CONSTRAINT [FK_lab_test_history_users] FOREIGN KEY([user_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[lab_test_history] CHECK CONSTRAINT [FK_lab_test_history_users]
GO

-- %% [markdown]
-- # [FK_dbo.lab_test_results_dbo.lab_tests_lab_tests_id]

-- %%
ALTER TABLE [dbo].[lab_test_results]  WITH CHECK ADD  CONSTRAINT [FK_dbo.lab_test_results_dbo.lab_tests_lab_tests_id] FOREIGN KEY([lab_tests_id])
REFERENCES [dbo].[lab_tests] ([id])
GO
ALTER TABLE [dbo].[lab_test_results] CHECK CONSTRAINT [FK_dbo.lab_test_results_dbo.lab_tests_lab_tests_id]
GO

-- %% [markdown]
-- # [FK_lab_test_results_tests]

-- %%
ALTER TABLE [dbo].[lab_test_results_new]  WITH CHECK ADD  CONSTRAINT [FK_lab_test_results_tests] FOREIGN KEY([test_id])
REFERENCES [dbo].[lab_tests_new] ([id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[lab_test_results_new] CHECK CONSTRAINT [FK_lab_test_results_tests]
GO

-- %% [markdown]
-- # [FK_lab_test_results_users]

-- %%
ALTER TABLE [dbo].[lab_test_results_new]  WITH CHECK ADD  CONSTRAINT [FK_lab_test_results_users] FOREIGN KEY([measured_by])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[lab_test_results_new] CHECK CONSTRAINT [FK_lab_test_results_users]
GO

-- %% [markdown]
-- # [FK_dbo.lab_tests_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[lab_tests]  WITH CHECK ADD  CONSTRAINT [FK_dbo.lab_tests_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[lab_tests] CHECK CONSTRAINT [FK_dbo.lab_tests_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.lab_tests_dbo.users_users_id1]

-- %%
ALTER TABLE [dbo].[lab_tests]  WITH CHECK ADD  CONSTRAINT [FK_dbo.lab_tests_dbo.users_users_id1] FOREIGN KEY([users_id1])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[lab_tests] CHECK CONSTRAINT [FK_dbo.lab_tests_dbo.users_users_id1]
GO

-- %% [markdown]
-- # [FK_dbo.lab_tests_dbo.users_users_id2]

-- %%
ALTER TABLE [dbo].[lab_tests]  WITH CHECK ADD  CONSTRAINT [FK_dbo.lab_tests_dbo.users_users_id2] FOREIGN KEY([users_id2])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[lab_tests] CHECK CONSTRAINT [FK_dbo.lab_tests_dbo.users_users_id2]
GO

-- %% [markdown]
-- # [FK_dbo.lab_tests_dbo.users_users1_id]

-- %%
ALTER TABLE [dbo].[lab_tests]  WITH CHECK ADD  CONSTRAINT [FK_dbo.lab_tests_dbo.users_users1_id] FOREIGN KEY([users1_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[lab_tests] CHECK CONSTRAINT [FK_dbo.lab_tests_dbo.users_users1_id]
GO

-- %% [markdown]
-- # [FK_lab_tests_users_created]

-- %%
ALTER TABLE [dbo].[lab_tests_new]  WITH CHECK ADD  CONSTRAINT [FK_lab_tests_users_created] FOREIGN KEY([created_by])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[lab_tests_new] CHECK CONSTRAINT [FK_lab_tests_users_created]
GO

-- %% [markdown]
-- # [FK_lab_tests_users_lab]

-- %%
ALTER TABLE [dbo].[lab_tests_new]  WITH CHECK ADD  CONSTRAINT [FK_lab_tests_users_lab] FOREIGN KEY([lab_user_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[lab_tests_new] CHECK CONSTRAINT [FK_lab_tests_users_lab]
GO

-- %% [markdown]
-- # [FK_dbo.production_batches_dbo.production_orders_production_orders_id]

-- %%
ALTER TABLE [dbo].[production_batches]  WITH CHECK ADD  CONSTRAINT [FK_dbo.production_batches_dbo.production_orders_production_orders_id] FOREIGN KEY([production_orders_id])
REFERENCES [dbo].[production_orders] ([id])
GO
ALTER TABLE [dbo].[production_batches] CHECK CONSTRAINT [FK_dbo.production_batches_dbo.production_orders_production_orders_id]
GO

-- %% [markdown]
-- # [FK_dbo.production_batches_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[production_batches]  WITH CHECK ADD  CONSTRAINT [FK_dbo.production_batches_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[production_batches] CHECK CONSTRAINT [FK_dbo.production_batches_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.production_orders_dbo.products_products_id]

-- %%
ALTER TABLE [dbo].[production_orders]  WITH CHECK ADD  CONSTRAINT [FK_dbo.production_orders_dbo.products_products_id] FOREIGN KEY([products_id])
REFERENCES [dbo].[products] ([id])
GO
ALTER TABLE [dbo].[production_orders] CHECK CONSTRAINT [FK_dbo.production_orders_dbo.products_products_id]
GO

-- %% [markdown]
-- # [FK_dbo.production_orders_dbo.recipes_recipes_id]

-- %%
ALTER TABLE [dbo].[production_orders]  WITH CHECK ADD  CONSTRAINT [FK_dbo.production_orders_dbo.recipes_recipes_id] FOREIGN KEY([recipes_id])
REFERENCES [dbo].[recipes] ([id])
GO
ALTER TABLE [dbo].[production_orders] CHECK CONSTRAINT [FK_dbo.production_orders_dbo.recipes_recipes_id]
GO

-- %% [markdown]
-- # [FK_dbo.production_orders_dbo.tech_maps_tech_maps_id]

-- %%
ALTER TABLE [dbo].[production_orders]  WITH CHECK ADD  CONSTRAINT [FK_dbo.production_orders_dbo.tech_maps_tech_maps_id] FOREIGN KEY([tech_maps_id])
REFERENCES [dbo].[tech_maps] ([id])
GO
ALTER TABLE [dbo].[production_orders] CHECK CONSTRAINT [FK_dbo.production_orders_dbo.tech_maps_tech_maps_id]
GO

-- %% [markdown]
-- # [FK_dbo.production_orders_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[production_orders]  WITH CHECK ADD  CONSTRAINT [FK_dbo.production_orders_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[production_orders] CHECK CONSTRAINT [FK_dbo.production_orders_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.raw_material_batches_dbo.raw_materials_raw_materials_id]

-- %%
ALTER TABLE [dbo].[raw_material_batches]  WITH CHECK ADD  CONSTRAINT [FK_dbo.raw_material_batches_dbo.raw_materials_raw_materials_id] FOREIGN KEY([raw_materials_id])
REFERENCES [dbo].[raw_materials] ([id])
GO
ALTER TABLE [dbo].[raw_material_batches] CHECK CONSTRAINT [FK_dbo.raw_material_batches_dbo.raw_materials_raw_materials_id]
GO

-- %% [markdown]
-- # [FK_dbo.raw_material_batches_dbo.suppliers_suppliers_id]

-- %%
ALTER TABLE [dbo].[raw_material_batches]  WITH CHECK ADD  CONSTRAINT [FK_dbo.raw_material_batches_dbo.suppliers_suppliers_id] FOREIGN KEY([suppliers_id])
REFERENCES [dbo].[suppliers] ([id])
GO
ALTER TABLE [dbo].[raw_material_batches] CHECK CONSTRAINT [FK_dbo.raw_material_batches_dbo.suppliers_suppliers_id]
GO

-- %% [markdown]
-- # [FK_dbo.recipe_components_dbo.raw_materials_raw_materials_id]

-- %%
ALTER TABLE [dbo].[recipe_components]  WITH CHECK ADD  CONSTRAINT [FK_dbo.recipe_components_dbo.raw_materials_raw_materials_id] FOREIGN KEY([raw_materials_id])
REFERENCES [dbo].[raw_materials] ([id])
GO
ALTER TABLE [dbo].[recipe_components] CHECK CONSTRAINT [FK_dbo.recipe_components_dbo.raw_materials_raw_materials_id]
GO

-- %% [markdown]
-- # [FK_dbo.recipe_components_dbo.recipes_recipes_id]

-- %%
ALTER TABLE [dbo].[recipe_components]  WITH CHECK ADD  CONSTRAINT [FK_dbo.recipe_components_dbo.recipes_recipes_id] FOREIGN KEY([recipes_id])
REFERENCES [dbo].[recipes] ([id])
GO
ALTER TABLE [dbo].[recipe_components] CHECK CONSTRAINT [FK_dbo.recipe_components_dbo.recipes_recipes_id]
GO

-- %% [markdown]
-- # [FK_dbo.recipes_dbo.products_products_id]

-- %%
ALTER TABLE [dbo].[recipes]  WITH CHECK ADD  CONSTRAINT [FK_dbo.recipes_dbo.products_products_id] FOREIGN KEY([products_id])
REFERENCES [dbo].[products] ([id])
GO
ALTER TABLE [dbo].[recipes] CHECK CONSTRAINT [FK_dbo.recipes_dbo.products_products_id]
GO

-- %% [markdown]
-- # [FK_dbo.recipes_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[recipes]  WITH CHECK ADD  CONSTRAINT [FK_dbo.recipes_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[recipes] CHECK CONSTRAINT [FK_dbo.recipes_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.recipes_dbo.users_users_id1]

-- %%
ALTER TABLE [dbo].[recipes]  WITH CHECK ADD  CONSTRAINT [FK_dbo.recipes_dbo.users_users_id1] FOREIGN KEY([users_id1])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[recipes] CHECK CONSTRAINT [FK_dbo.recipes_dbo.users_users_id1]
GO

-- %% [markdown]
-- # [FK_dbo.recipes_dbo.users_users_id2]

-- %%
ALTER TABLE [dbo].[recipes]  WITH CHECK ADD  CONSTRAINT [FK_dbo.recipes_dbo.users_users_id2] FOREIGN KEY([users_id2])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[recipes] CHECK CONSTRAINT [FK_dbo.recipes_dbo.users_users_id2]
GO

-- %% [markdown]
-- # [FK_dbo.recipes_dbo.users_users1_id]

-- %%
ALTER TABLE [dbo].[recipes]  WITH CHECK ADD  CONSTRAINT [FK_dbo.recipes_dbo.users_users1_id] FOREIGN KEY([users1_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[recipes] CHECK CONSTRAINT [FK_dbo.recipes_dbo.users_users1_id]
GO

-- %% [markdown]
-- # [FK_dbo.step_executions_dbo.equipments_equipment_id1]

-- %%
ALTER TABLE [dbo].[step_executions]  WITH CHECK ADD  CONSTRAINT [FK_dbo.step_executions_dbo.equipments_equipment_id1] FOREIGN KEY([equipment_id1])
REFERENCES [dbo].[equipments] ([id])
GO
ALTER TABLE [dbo].[step_executions] CHECK CONSTRAINT [FK_dbo.step_executions_dbo.equipments_equipment_id1]
GO

-- %% [markdown]
-- # [FK_dbo.step_executions_dbo.production_batches_production_batches_id]

-- %%
ALTER TABLE [dbo].[step_executions]  WITH CHECK ADD  CONSTRAINT [FK_dbo.step_executions_dbo.production_batches_production_batches_id] FOREIGN KEY([production_batches_id])
REFERENCES [dbo].[production_batches] ([id])
GO
ALTER TABLE [dbo].[step_executions] CHECK CONSTRAINT [FK_dbo.step_executions_dbo.production_batches_production_batches_id]
GO

-- %% [markdown]
-- # [FK_dbo.step_executions_dbo.tech_steps_tech_steps_id]

-- %%
ALTER TABLE [dbo].[step_executions]  WITH CHECK ADD  CONSTRAINT [FK_dbo.step_executions_dbo.tech_steps_tech_steps_id] FOREIGN KEY([tech_steps_id])
REFERENCES [dbo].[tech_steps] ([id])
GO
ALTER TABLE [dbo].[step_executions] CHECK CONSTRAINT [FK_dbo.step_executions_dbo.tech_steps_tech_steps_id]
GO

-- %% [markdown]
-- # [FK_dbo.step_executions_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[step_executions]  WITH CHECK ADD  CONSTRAINT [FK_dbo.step_executions_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[step_executions] CHECK CONSTRAINT [FK_dbo.step_executions_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.step_executions_dbo.users_users_id1]

-- %%
ALTER TABLE [dbo].[step_executions]  WITH CHECK ADD  CONSTRAINT [FK_dbo.step_executions_dbo.users_users_id1] FOREIGN KEY([users_id1])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[step_executions] CHECK CONSTRAINT [FK_dbo.step_executions_dbo.users_users_id1]
GO

-- %% [markdown]
-- # [FK_dbo.step_executions_dbo.users_users_id2]

-- %%
ALTER TABLE [dbo].[step_executions]  WITH CHECK ADD  CONSTRAINT [FK_dbo.step_executions_dbo.users_users_id2] FOREIGN KEY([users_id2])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[step_executions] CHECK CONSTRAINT [FK_dbo.step_executions_dbo.users_users_id2]
GO

-- %% [markdown]
-- # [FK_dbo.step_executions_dbo.users_users1_id]

-- %%
ALTER TABLE [dbo].[step_executions]  WITH CHECK ADD  CONSTRAINT [FK_dbo.step_executions_dbo.users_users1_id] FOREIGN KEY([users1_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[step_executions] CHECK CONSTRAINT [FK_dbo.step_executions_dbo.users_users1_id]
GO

-- %% [markdown]
-- # [FK_dbo.tech_maps_dbo.equipments_equipment_id1]

-- %%
ALTER TABLE [dbo].[tech_maps]  WITH CHECK ADD  CONSTRAINT [FK_dbo.tech_maps_dbo.equipments_equipment_id1] FOREIGN KEY([equipment_id1])
REFERENCES [dbo].[equipments] ([id])
GO
ALTER TABLE [dbo].[tech_maps] CHECK CONSTRAINT [FK_dbo.tech_maps_dbo.equipments_equipment_id1]
GO

-- %% [markdown]
-- # [FK_dbo.tech_maps_dbo.recipes_recipes_id]

-- %%
ALTER TABLE [dbo].[tech_maps]  WITH CHECK ADD  CONSTRAINT [FK_dbo.tech_maps_dbo.recipes_recipes_id] FOREIGN KEY([recipes_id])
REFERENCES [dbo].[recipes] ([id])
GO
ALTER TABLE [dbo].[tech_maps] CHECK CONSTRAINT [FK_dbo.tech_maps_dbo.recipes_recipes_id]
GO

-- %% [markdown]
-- # [FK_dbo.tech_maps_dbo.users_users_id]

-- %%
ALTER TABLE [dbo].[tech_maps]  WITH CHECK ADD  CONSTRAINT [FK_dbo.tech_maps_dbo.users_users_id] FOREIGN KEY([users_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[tech_maps] CHECK CONSTRAINT [FK_dbo.tech_maps_dbo.users_users_id]
GO

-- %% [markdown]
-- # [FK_dbo.tech_maps_dbo.users_users_id1]

-- %%
ALTER TABLE [dbo].[tech_maps]  WITH CHECK ADD  CONSTRAINT [FK_dbo.tech_maps_dbo.users_users_id1] FOREIGN KEY([users_id1])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[tech_maps] CHECK CONSTRAINT [FK_dbo.tech_maps_dbo.users_users_id1]
GO

-- %% [markdown]
-- # [FK_dbo.tech_maps_dbo.users_users_id2]

-- %%
ALTER TABLE [dbo].[tech_maps]  WITH CHECK ADD  CONSTRAINT [FK_dbo.tech_maps_dbo.users_users_id2] FOREIGN KEY([users_id2])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[tech_maps] CHECK CONSTRAINT [FK_dbo.tech_maps_dbo.users_users_id2]
GO

-- %% [markdown]
-- # [FK_dbo.tech_maps_dbo.users_users1_id]

-- %%
ALTER TABLE [dbo].[tech_maps]  WITH CHECK ADD  CONSTRAINT [FK_dbo.tech_maps_dbo.users_users1_id] FOREIGN KEY([users1_id])
REFERENCES [dbo].[users] ([id])
GO
ALTER TABLE [dbo].[tech_maps] CHECK CONSTRAINT [FK_dbo.tech_maps_dbo.users_users1_id]
GO

-- %% [markdown]
-- # [FK_dbo.tech_steps_dbo.equipments_equipment_id1]

-- %%
ALTER TABLE [dbo].[tech_steps]  WITH CHECK ADD  CONSTRAINT [FK_dbo.tech_steps_dbo.equipments_equipment_id1] FOREIGN KEY([equipment_id1])
REFERENCES [dbo].[equipments] ([id])
GO
ALTER TABLE [dbo].[tech_steps] CHECK CONSTRAINT [FK_dbo.tech_steps_dbo.equipments_equipment_id1]
GO

-- %% [markdown]
-- # [FK_dbo.tech_steps_dbo.tech_maps_tech_maps_id]

-- %%
ALTER TABLE [dbo].[tech_steps]  WITH CHECK ADD  CONSTRAINT [FK_dbo.tech_steps_dbo.tech_maps_tech_maps_id] FOREIGN KEY([tech_maps_id])
REFERENCES [dbo].[tech_maps] ([id])
GO
ALTER TABLE [dbo].[tech_steps] CHECK CONSTRAINT [FK_dbo.tech_steps_dbo.tech_maps_tech_maps_id]
GO

-- %% [markdown]
-- # [FK_test_protocol_parameters_templates]

-- %%
ALTER TABLE [dbo].[test_protocol_parameters]  WITH CHECK ADD  CONSTRAINT [FK_test_protocol_parameters_templates] FOREIGN KEY([template_id])
REFERENCES [dbo].[test_protocol_templates] ([id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[test_protocol_parameters] CHECK CONSTRAINT [FK_test_protocol_parameters_templates]
GO

-- %% [markdown]
-- # [FK_dbo.users_dbo.departments_departments_id]

-- %%
ALTER TABLE [dbo].[users]  WITH CHECK ADD  CONSTRAINT [FK_dbo.users_dbo.departments_departments_id] FOREIGN KEY([departments_id])
REFERENCES [dbo].[departments] ([id])
GO
ALTER TABLE [dbo].[users] CHECK CONSTRAINT [FK_dbo.users_dbo.departments_departments_id]
GO

-- %% [markdown]
-- # [FK_dbo.users_dbo.roles_roles_id]

-- %%
ALTER TABLE [dbo].[users]  WITH CHECK ADD  CONSTRAINT [FK_dbo.users_dbo.roles_roles_id] FOREIGN KEY([roles_id])
REFERENCES [dbo].[roles] ([id])
GO
ALTER TABLE [dbo].[users] CHECK CONSTRAINT [FK_dbo.users_dbo.roles_roles_id]
GO
